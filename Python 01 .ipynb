# %% [markdown]
# TASK # 01: Write a code to greet your audience.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# TASK # 02: Write a code to print "Error! Please Enter a Valid Password" .

# %%
print("Error! Please Enter a Valid Password")
# Out:
# Error! Please Enter a Valid Password

# %% [markdown]
# TASK # 03: . Write a code to display following message. (Hint : Use line break)

# %%
print("Welcome to Python Land \n Hello Coding ")
# Out:
# Welcome to Python Land
#  Hello Coding

# %% [markdown]
# TASK # 04: Write a code to display the following message.

# %%
print("hello....I can run Python through Browser ")
# Out:
# hello....I can run Python through Browser
